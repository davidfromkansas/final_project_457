# %%
import json
import textstat
from textatistic import Textatistic # http://www.erinhengel.com/software/textatistic/
import textatistic
from unidecode import unidecode
import csv



# we want an array of objects where each object represents a story
everything = {}

# Get SubBorough Names
with open("./raw_data/median_household_income.csv") as f:
    readCSV = csv.reader(f, delimiter=',')
    for index,row in enumerate(readCSV):      # each row will represent another city
        if(index != 0):
            everything[row[2]] = {}

years = [2000,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016]

with open("./raw_data/median_household_income.csv") as f:
    readCSV = csv.reader(f, delimiter=',')
    for index,row in enumerate(readCSV):      # each row will represent another city
        if(index != 0):
            kebab = {}
            kebab["subborough"] = row[2]
            start = 3
            for year in years:
                kebab[year] = int(float(row[start]))
                start = start + 1
            
            everything[row[2]]["median_household_income"] = kebab
                
with open("./raw_data/population.csv") as f:
    readCSV = csv.reader(f, delimiter=',')
    for index,row in enumerate(readCSV):      # each row will represent another city
        if(index != 0):
            kebab = {}
            kebab["subborough"] = row[2]
            start = 3
            for year in years:
                kebab[year] = int(float(row[start]))
                start = start + 1
            everything[row[2]]["population"] = kebab


# Definition: The probability that two randomly chosen people in a given geographic area will be of a different race.
with open("./raw_data/racial_diversity_index.csv") as f:  #
    readCSV = csv.reader(f, delimiter=',')

    for index,row in enumerate(readCSV):      # each row will represent another city
        if(index != 0):
            kebab1 = {}
            kebab1["subborough"] = row[2]
            start = 3
            for year in years:
                if(row[start]):
                    kebab1[year] = round(float(row[start])*100,1)
                else:
                    kebab1[year] = "none"
                start = start + 1
            everything[row[2]]["racial_diversity_index"] = kebab1

            
            
            
# Definition: The number of people below the poverty threshold divided by the number of people for whom poverty status was determined.
with open("./raw_data/poverty_rate.csv") as f:  #
    readCSV = csv.reader(f, delimiter=',')

    for index,row in enumerate(readCSV):      # each row will represent another city
        if(index != 0):
            kebab = {}
            kebab["subborough"] = row[2]
            start = 3
            for year in years:
                if(row[start]):
                    kebab[year] = round(float(row[start])*100,1)
                else:
                    kebab[year] = "none"
                start = start + 1
            everything[row[2]]["poverty_rate"] = kebab


with open("./raw_data/unemployment_rate.csv") as f:  #
    readCSV = csv.reader(f, delimiter=',')

    for index,row in enumerate(readCSV):      # each row will represent another city
        if(index != 0):
            kebab = {}
            kebab["subborough"] = row[2]
            start = 3
            for year in years:
                if(row[start]):
                    kebab[year] = round(float(row[start])*100,1)
                else:
                    kebab[year] = "none"
                start = start + 1
            everything[row[2]]["unemployment_rate"] = kebab

                
with open("./raw_data/percent_white.csv") as f:  #
    readCSV = csv.reader(f, delimiter=',')

    for index,row in enumerate(readCSV):      # each row will represent another city
        if(index != 0):
            kebab = {}
            kebab["subborough"] = row[2]
            start = 3
            for year in years:
                if(row[start]):
                    kebab[year] = round(float(row[start])*100,1)
                else:
                    kebab[year] = "none"
                start = start + 1
            everything[row[2]]["percent_white"] = kebab


with open("./raw_data/percent_black.csv") as f:  #
    readCSV = csv.reader(f, delimiter=',')

    for index,row in enumerate(readCSV):      # each row will represent another city
        if(index != 0):
            kebab = {}
            kebab["subborough"] = row[2]
            start = 3
            for year in years:
                if(row[start]):
                    kebab[year] = round(float(row[start])*100,1)
                else:
                    kebab[year] = "none"
                start = start + 1
            everything[row[2]]["percent_black"] = kebab

                
with open("./raw_data/percent_hispanic.csv") as f:  #
    readCSV = csv.reader(f, delimiter=',')

    for index,row in enumerate(readCSV):      # each row will represent another city
        if(index != 0):
            kebab = {}
            kebab["subborough"] = row[2]
            start = 3
            for year in years:
                if(row[start]):
                    kebab[year] = round(float(row[start])*100,1)
                else:
                    kebab[year] = "none"
                start = start + 1
            everything[row[2]]["percent_hispanic"] = kebab


with open("./raw_data/percent_asian.csv") as f:  #
    readCSV = csv.reader(f, delimiter=',')

    for index,row in enumerate(readCSV):      # each row will represent another city
        if(index != 0):
            kebab = {}
            kebab["subborough"] = row[2]
            start = 3
            for year in years:
                if(row[start]):
                    kebab[year] = round(float(row[start])*100,1)
                else:
                    kebab[year] = "none"
                start = start + 1
            everything[row[2]]["percent_asian"] = kebab

            
            
            
  
with open('data.json', 'w') as outfile:
    json.dump(everything, outfile)
